# %%
import io
import base64
from IPython.display import HTML

#Don't use big videos for eg. > 10MB

video_file = "/media/phani/Windows Drive/Videos/TVSHOWS/JAPANESE/Gintama/Gintama_Season_8_Episode_356-0.mp4"

video = io.open(video_file, 'r+b').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" width="800" controls loop>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" width="800" controls loop>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
import re
import math
from optparse import OptionParser

length_regexp = 'Duration: (\d{2}):(\d{2}):(\d{2})\.\d+,'
re_length = re.compile(length_regexp)

from subprocess import check_call, PIPE, Popen
import shlex

def main():
    filename, split_length = "/media/phani/Windows Drive/Videos/TVSHOWS/JAPNANESE/Gintama/Gintama_Season_8_Episode_356.mp4", 30
    if split_length <= 0:
        print("Split length can't be 0")
        raise SystemExit

    p1 = Popen(["ffmpeg", "-i", filename], stdout=PIPE, stderr=PIPE, universal_newlines=True)
    # get p1.stderr as input
    output = Popen(["grep", 'Duration'], stdin=p1.stderr, stdout=PIPE, universal_newlines=True)
    p1.stdout.close()
    matches = re_length.search(output.stdout.read())
    if matches:
        video_length = int(matches.group(1)) * 3600 + \
                       int(matches.group(2)) * 60 + \
                       int(matches.group(3))
        print("Video length in seconds: {}".format(video_length))
    else:
        print("Can't determine video length.")
        raise SystemExit

    split_count = math.ceil(video_length / split_length)

    if split_count == 1:
        print("Video length is less than the target split length.")
        raise SystemExit

    for n in range(split_count):
        split_start = split_length * n
        pth, ext = filename.rsplit(".", 1)
        cmd = "ffmpeg -i {} -vcodec copy  -strict -2 -ss {} -t {} {}-{}.{}".\
            format(filename, split_start, split_length, pth, n, ext)
        print("About to run: {}".format(cmd))
        check_call(shlex.split(cmd), universal_newlines=True)


if __name__ == '__main__':
    try:
        main()
    except Exception as e:
        print(e)
# Out:
# Can't determine video length.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2971: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# !ffmpeg -i /media/phani/Windows\ Drive/Videos/TVSHOWS/JAPNANESE/Gintama/Gintama_Season_8_Episode_356.mp4 -vcodec copy  -strict -2 -ss 0 -t 30 /media/phani/Windows\ Drive/Videos/TVSHOWS/JAPNANESE/Gintama/Gintama_Season_8_Episode_356-0.mp4
# Out:
# ffmpeg version 2.8.14-0ubuntu0.16.04.1 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 5.4.0 (Ubuntu 5.4.0-6ubuntu1~16.04.9) 20160609
# ...

# %%
# %ls -lh /media/phani/Windows\ Drive/Videos/TVSHOWS/JAPANESE/Gintama/Gintama_Season_8_Episode_356-0.mp4
# Out:
# -rwxrwxrwx 1 phani phani 2.3M Jul 24 22:40 /media/phani/Windows Drive/Videos/TVSHOWS/JAPANESE/Gintama/Gintama_Season_8_Episode_356-0.mp4*

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <ipython-input-4-37fb2a337e44> in <module>()
#      43 if __name__ == '__main__':
#      44     try:
# ---> 45         main()
#      46     except Exception as e:
#      47         print(e)
#
# <ipython-input-4-37fb2a337e44> in main()
#      25     else:
#      26         print("Can't determine video length.")
# ---> 27         raise SystemExit
#      28
#      29     split_count = math.ceil(video_length / split_length)
#
# SystemExit:

# %%
ls
# Out:
# Anime_Downloader (1).md  Figureplayercdn.ipynb  onepieceredtowhite.png
# Anime_Downloader.ipynb   Imageresizing.ipynb    __pycache__/
# Anime_Downloader.md      Ipythontests.ipynb     tens.py
# Anime_Downloader.py      kaggle.ipynb           twist.html
# ApplesandOranges.ipynb   masterani.ipynb        twist.moe.ipynb
# assets/                  Myheroacademia.ipynb   untitled.py
# downlo.txt               named_colors.py
# dynamic_image.ipynb      onepiece17.png

# %%
# %%python
#
# def shit():
#     return "ss"

# %%
# !echo $HOME
# Out:
# /home/phani

# %%
shit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-36d89a3cadcd> in <module>()
# ----> 1 shit
#
# NameError: name 'shit' is not defined

# %%
# %matplotlib inline
